# %% [markdown]
# ### Set up

# %% [markdown]
# #### 1. Set  up  accounts and role

# %%
import sagemaker
import boto3
from uuid import uuid4

sagemaker_session = sagemaker.Session()
account_id =  boto3.client('sts').get_caller_identity().get('Account')
region = boto3.session.Session().region_name


#role = sagemaker.get_execution_role()
role="arn:aws:iam::{}:role/service-role/AmazonSageMaker-ExecutionRole-20190118T115449".format(account_id)
step_func_role = "arn:aws:iam::{}:role/AmazonSageMaker-StepFunctionsWorkflowExecutionRole".format(account_id)
max_runs=1
# Out:
# /Users/aparnaelangovan/PycharmProjects/venv/HiddenCut/lib/python3.7/site-packages/boto3/compat.py:82: PythonDeprecationWarning: Boto3 will no longer support Python 3.7 starting December 13, 2023. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.8 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)

# %%
# docker_repo = "{}.dkr.ecr.{}.amazonaws.com/{}".format(account_id, region, pytorch_custom_image_name)

# %%
jobs_imdb5h = [
 "hiddencut-imdb5h-05-2023-09-10-05-26-10-644",
"hiddencut-imdb5h-04-2023-09-10-05-26-08-989",
"hiddencut-imdb5h-03-2023-09-10-05-26-07-329",
"hiddencut-imdb5h-02-2023-09-10-05-26-04-684",
"hiddencut-imdb5h-01-2023-09-10-05-26-01-739",
"hiddencut-imdb5h-base-05-2023-09-10-05-25-59-853",
"hiddencut-imdb5h-base-04-2023-09-10-05-25-58-199",
"hiddencut-imdb5h-base-03-2023-09-10-05-25-56-549",
"hiddencut-imdb5h-base-02-2023-09-10-05-25-53-654",
"hiddencut-imdb5h-base-01-2023-09-10-05-25-50-657",
"hiddencut-hiddencut-imdb2k-base-05-2023-09-11-04-41-43-209",
"hiddencut-hiddencut-imdb2k-base-04-2023-09-11-04-41-41-355",
"hiddencut-hiddencut-imdb2k-base-03-2023-09-11-04-41-39-394",
"hiddencut-hiddencut-imdb2k-base-02-2023-09-11-04-41-36-540",
"hiddencut-hiddencut-imdb2k-base-01-2023-09-11-04-41-34-574",
"hiddencut-hiddencut-imdb2k-05-2023-09-12-01-14-41-067",
"hiddencut-hiddencut-imdb2k-04-2023-09-12-01-14-39-180",
"hiddencut-hiddencut-imdb2k-03-2023-09-12-01-14-36-090",
"hiddencut-hiddencut-imdb2k-02-2023-09-12-01-14-32-661",
"hiddencut-hiddencut-imdb2k-01-2023-09-12-01-14-28-395"
]

jobs_sst = ["hiddencut-sst-contrast-base-2023-09-10-18-46-14-367",
           "hiddencut-sst-contrast-2023-09-10-18-46-10-526"
           ]

jobs = jobs_sst

output_prefix = "s3://aegovan-data/hiddencut_sagemakerresults/{}/output/output.tar.gz"

# %%
import io

def get_bucketname_key(uripath):
    assert uripath.startswith("s3://")

    path_without_scheme = uripath[5:]
    bucket_end_index = path_without_scheme.find("/")

    bucket_name = path_without_scheme
    key = "/"
    if bucket_end_index > -1:
        bucket_name = path_without_scheme[0:bucket_end_index]
        key = path_without_scheme[bucket_end_index + 1:]

    return bucket_name, key

def download_binary_object(s3path):
    bucket, key = get_bucketname_key(s3path)

    s3 = boto3.client('s3')

    s3_response_object = s3.get_object(Bucket=bucket, Key=key)
    object_content = io.BytesIO(s3_response_object['Body'].read())
    
    return object_content

# %%
import tarfile, json


def extract_tar_json(fileobj):
    with tarfile.open(fileobj=fileobj) as f:
        for member in f:
            # You need additional code to save the data into a list.
            file_content_byte = f.extractfile(member.name)
            yield  json.loads(file_content_byte.read().decode("utf-8"))

# %%
import sagemaker

def get_training_job_details(job_name):
    client = boto3.client('sagemaker')
    response = client.describe_training_job(
    TrainingJobName=job_name
)
    input_data =  response["InputDataConfig"]
    is_augmentation = int(response["HyperParameters"].get("do_aug","0"))
    model_name = "roberta-base"
    if is_augmentation:
        model_name = model_name + "hidden-cut"
    train_data = list(filter(lambda x: x["ChannelName"].lower() == 'all', input_data ))[0]["DataSource"]["S3DataSource"]["S3Uri"]
    train_data = train_data.replace("s3://aegovan-data/glue_full_set/","")[:14]
    return train_data, model_name

# %%
import pandas as pd
pd.set_option('display.max_rows', 100)

def download_results(job_name):
    output_uri = output_prefix.format(job_name)
    print(output_uri)
    results =  list(extract_tar_json(download_binary_object(output_uri)))
    assert len(results) == 2, "Expect only 2 result files"
    df_1,df_2 = pd.DataFrame(results[0]), pd.DataFrame(results[1])
    df = df_1.merge(df_2, how='outer', on="step", left_index=False, right_index=False)
    df["output_uri"] = output_uri
    train_data, model = get_training_job_details(job_name)
    df["model"] = model
    df["train_data"] = train_data
            
    return df
    
def download_all_results(jobs):
    result = []
    for j in jobs:
        df = download_results(j)
        result.append(df)
    return pd.concat(result)
        
df_sst = download_all_results (jobs_sst)  
df_imdb = download_all_results (jobs_imdb5h)
# Out:
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-sst-contrast-base-2023-09-10-18-46-14-367/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-sst-contrast-2023-09-10-18-46-10-526/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-imdb5h-05-2023-09-10-05-26-10-644/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-imdb5h-04-2023-09-10-05-26-08-989/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-imdb5h-03-2023-09-10-05-26-07-329/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-imdb5h-02-2023-09-10-05-26-04-684/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-imdb5h-01-2023-09-10-05-26-01-739/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-imdb5h-base-05-2023-09-10-05-25-59-853/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-imdb5h-base-04-2023-09-10-05-25-58-199/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-imdb5h-base-03-2023-09-10-05-25-56-549/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-imdb5h-base-02-2023-09-10-05-25-53-654/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-imdb5h-base-01-2023-09-10-05-25-50-657/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-hiddencut-imdb2k-base-05-2023-09-11-04-41-43-209/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-hiddencut-imdb2k-base-04-2023-09-11-04-41-41-355/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-hiddencut-imdb2k-base-03-2023-09-11-04-41-39-394/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-hiddencut-imdb2k-base-02-2023-09-11-04-41-36-540/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-hiddencut-imdb2k-base-01-2023-09-11-04-41-34-574/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-hiddencut-imdb2k-05-2023-09-12-01-14-41-067/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-hiddencut-imdb2k-04-2023-09-12-01-14-39-180/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-hiddencut-imdb2k-03-2023-09-12-01-14-36-090/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-hiddencut-imdb2k-02-2023-09-12-01-14-32-661/output/output.tar.gz
# s3://aegovan-data/hiddencut_sagemakerresults/hiddencut-hiddencut-imdb2k-01-2023-09-12-01-14-28-395/output/output.tar.gz

# %%
df_sst.head()
# Out:
#    step  constrastsetimdb_acc  constrastsetimdb_loss  \
# 0  2650              0.907787                0.23636
# 1    50                   NaN                    NaN
# 2   100                   NaN                    NaN
# 3   150                   NaN                    NaN
# 4   200                   NaN                    NaN
#
#    constrastsetimdboriginal_acc  constrastsetimdboriginal_loss  eval_acc  \
# 0                      0.922131                       0.247688  0.949541
# 1                           NaN                            NaN  0.490826
# 2                           NaN                            NaN  0.490826
# 3                           NaN                            NaN  0.490826
# 4                           NaN                            NaN  0.509174
#
#    eval_loss                                         output_uri         model  \
# 0   0.180160  s3://aegovan-data/hiddencut_sagemakerresults/h...  roberta-base
# 1   0.699888  s3://aegovan-data/hiddencut_sagemakerresults/h...  roberta-base
# 2   0.696311  s3://aegovan-data/hiddencut_sagemakerresults/h...  roberta-base
# 3   0.692690  s3://aegovan-data/hiddencut_sagemakerresults/h...  roberta-base
# 4   0.690357  s3://aegovan-data/hiddencut_sagemakerresults/h...  roberta-base
#
#        train_data
# 0  sst-2-contrast
# 1  sst-2-contrast
# 2  sst-2-contrast
# 3  sst-2-contrast
# 4  sst-2-contrast

# %%
df_sst[~df_sst["constrastsetimdb_acc"].isna()].T
# Out:
#                                                                              0    \
# step                                                                        2650
# constrastsetimdb_acc                                                    0.907787
# constrastsetimdb_loss                                                    0.23636
# constrastsetimdboriginal_acc                                            0.922131
# constrastsetimdboriginal_loss                                           0.247688
# eval_acc                                                                0.949541
# eval_loss                                                                0.18016
# output_uri                     s3://aegovan-data/hiddencut_sagemakerresults/h...
# model                                                               roberta-base
# train_data                                                        sst-2-contrast
#
#                                                                              109
# step                                                                        5260
# constrastsetimdb_acc                                                    0.918033
# constrastsetimdb_loss                                                   0.252119
# constrastsetimdboriginal_acc                                            0.915984
# constrastsetimdboriginal_loss                                           0.316355
# eval_acc                                                                0.951835
# eval_loss                                                               0.181109
# output_uri                     s3://aegovan-data/hiddencut_sagemakerresults/h...
# model                                                     roberta-basehidden-cut
# train_data                                                        sst-2-contrast

# %%
df_sst["step"].describe()
# Out:
# count     267.000000
# mean     3368.449438
# std      2060.446607
# min        50.000000
# 25%      1650.000000
# 50%      3200.000000
# 75%      4825.000000
# max      7700.000000
# Name: step, dtype: float64

# %%
df_sst["eval_acc"].describe()
# Out:
# count    267.000000
# mean       0.920854
# std        0.088231
# min        0.490826
# 25%        0.935206
# 50%        0.941514
# 75%        0.944954
# max        0.951835
# Name: eval_acc, dtype: float64

# %%
df_imdb[~df_imdb["yelppolarity_acc"].isna()]\
    [["eval_acc", "yelppolarity_acc", "semeval4_acc", "amazonpolarity_acc", "model","train_data", "step"]]
# Out:
#     eval_acc  yelppolarity_acc  semeval4_acc  amazonpolarity_acc  \
# 13  0.920000          0.906808      0.796177            0.879455
# 0   0.933333          0.921840      0.875597            0.910238
# 13  0.920000          0.928684      0.872137            0.910285
# 20  0.906667          0.925499      0.808535            0.908070
# 15  0.933333          0.927789      0.857802            0.916748
# 13  0.920000          0.918839      0.843632            0.895077
# 0   0.933333          0.926552      0.888449            0.917820
# 13  0.920000          0.931896      0.885484            0.918750
# 0   0.880000          0.926499      0.866370            0.911090
# 0   0.933333          0.916496      0.858296            0.905293
# 10  0.933333          0.933607      0.802109            0.919362
# 9   0.940000          0.932422      0.806887            0.903027
# 24  0.960000          0.929263      0.840501            0.908613
# 0   0.933333          0.930764      0.770802            0.893173
# 0   0.946667          0.929711      0.769814            0.906998
# 14  0.936667          0.935897      0.797825            0.924992
# 0   0.943333          0.931185      0.811007            0.901290
# 16  0.963333          0.932475      0.815126            0.912857
# 21  0.930000          0.933028      0.782336            0.904162
# 0   0.953333          0.921050      0.755973            0.886258
#
#                      model      train_data  step
# 13  roberta-basehidden-cut  imdb/imdb-5h/2    91
# 0   roberta-basehidden-cut  imdb/imdb-5h/2    77
# 13  roberta-basehidden-cut  imdb/imdb-5h/2    91
# 20  roberta-basehidden-cut  imdb/imdb-5h/2   133
# 15  roberta-basehidden-cut  imdb/imdb-5h/2   100
# 13            roberta-base  imdb/imdb-5h/2    91
# 0             roberta-base  imdb/imdb-5h/2    98
# 13            roberta-base  imdb/imdb-5h/2    91
# 0             roberta-base  imdb/imdb-5h/2   119
# 0             roberta-base  imdb/imdb-5h/2   105
# 10            roberta-base  imdb/imdb-2k/2   217
# 9             roberta-base  imdb/imdb-2k/2   200
# 24            roberta-base  imdb/imdb-2k/2   496
# 0             roberta-base  imdb/imdb-2k/2   300
# 0             roberta-base  imdb/imdb-2k/2   279
# 14  roberta-basehidden-cut  imdb/imdb-2k/2   300
# 0   roberta-basehidden-cut  imdb/imdb-2k/2   372
# 16  roberta-basehidden-cut  imdb/imdb-2k/2   341
# 21  roberta-basehidden-cut  imdb/imdb-2k/2   434
# 0   roberta-basehidden-cut  imdb/imdb-2k/2   600

# %%
df_imdb[~df_imdb["yelppolarity_acc"].isna()]\
    [["eval_acc", "yelppolarity_acc", "semeval4_acc", 
      "amazonpolarity_acc", "model","train_data"]].groupby(["train_data","model"]).agg(("mean", "sem", "count"))
# Out:
#                                        eval_acc                  \
#                                            mean       sem count
# train_data     model
# imdb/imdb-2k/2 roberta-base            0.942667  0.004989     5
#                roberta-basehidden-cut  0.945333  0.005925     5
# imdb/imdb-5h/2 roberta-base            0.917333  0.009798     5
#                roberta-basehidden-cut  0.922667  0.004989     5
#
#                                       yelppolarity_acc                  \
#                                                   mean       sem count
# train_data     model
# imdb/imdb-2k/2 roberta-base                   0.931154  0.000820     5
#                roberta-basehidden-cut         0.930727  0.002539     5
# imdb/imdb-5h/2 roberta-base                   0.924056  0.002811     5
#                roberta-basehidden-cut         0.922124  0.004007     5
#
#                                       semeval4_acc                  \
#                                               mean       sem count
# train_data     model
# imdb/imdb-2k/2 roberta-base               0.798023  0.013108     5
#                roberta-basehidden-cut     0.792453  0.010771     5
# imdb/imdb-5h/2 roberta-base               0.868446  0.008407     5
#                roberta-basehidden-cut     0.842050  0.016593     5
#
#                                       amazonpolarity_acc
#                                                     mean       sem count
# train_data     model
# imdb/imdb-2k/2 roberta-base                     0.906235  0.004240     5
#                roberta-basehidden-cut           0.905912  0.006415     5
# imdb/imdb-5h/2 roberta-base                     0.909606  0.004376     5
#                roberta-basehidden-cut           0.904959  0.006540     5
